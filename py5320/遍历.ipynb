# %%
import os
import os.path
# This folder is custom
rootdir = './'
for parent, dirnames, filenames in os.walk(rootdir):
    # Case1: traversal the directories
    for dirname in dirnames:
        print("Parent folder:", parent)
        print("Dirname:", dirname)
    # Case2: traversal the files
    for filename in filenames:
        print("Parent folder:", parent)
        print("Filename:", filename)
# print(os.system("tree"))
# Out:
# Parent folder: ./
# Dirname: .ssh
# Parent folder: ./
# Dirname: storage
# Parent folder: ./
# Dirname: .cache
# Parent folder: ./
# Dirname: .local
# Parent folder: ./
# Dirname: .jupyter
# Parent folder: ./
# Dirname: .ipynb_checkpoints
# Parent folder: ./
# Dirname: .ipython
# Parent folder: ./
# Filename: .python_history
# Parent folder: ./
# Filename: .bash_history
# Parent folder: ./
# Filename: .termux_authinfo
# Parent folder: ./
# Filename: helloworl
# Parent folder: ./
# Filename: .viminfo
# Parent folder: ./
# Filename: sdjk.py
# Parent folder: ./
# Filename: 中文.txt
# Parent folder: ./
# Filename: 来.py
# Parent folder: ./
# Filename: duihua.py
# Parent folder: ./
# Filename: motd
# Parent folder: ./
# Filename: 字符串.ipynb
# Parent folder: ./
# Filename: piplist
# Parent folder: ./
# Filename: 遍历.ipynb
# Parent folder: ./
# Filename: 正则.ipynb
# Parent folder: ./
# Filename: .test.py.swp
# Parent folder: ./
# Filename: bianli.py
# Parent folder: ./
# Filename: pai.py
# Parent folder: ./
# Filename: pai2.py
# Parent folder: ./
# Filename: pai3.py
# Parent folder: ./
# Filename: pai1.py
# Parent folder: ./
# Filename: .vimrc
# Parent folder: ./
# Filename: pay.py
# Parent folder: ./.ssh
# Filename: authorized_keys
# Parent folder: ./.ssh
# Filename: Identity.pub
# Parent folder: ./.ssh
# Filename: authorized_keysbak
# Parent folder: ./storage
# Dirname: shared
# Parent folder: ./storage
# Dirname: downloads
# Parent folder: ./storage
# Dirname: dcim
# Parent folder: ./storage
# Dirname: pictures
# Parent folder: ./storage
# Dirname: movies
# Parent folder: ./storage
# Filename: music
# Parent folder: ./.cache
# Dirname: pip
# Parent folder: ./.cache
# Dirname: parso
# Parent folder: ./.cache
# Dirname: jedi
# Parent folder: ./.cache/pip
# Dirname: http
# Parent folder: ./.cache/pip
# Dirname: selfcheck
# Parent folder: ./.cache/pip
# Filename: selfcheck.json
# Parent folder: ./.cache/pip/http
# Dirname: a
# Parent folder: ./.cache/pip/http
# Dirname: 7
# Parent folder: ./.cache/pip/http
# Dirname: 4
# Parent folder: ./.cache/pip/http
# Dirname: 8
# Parent folder: ./.cache/pip/http
# Dirname: 2
# Parent folder: ./.cache/pip/http
# Dirname: f
# Parent folder: ./.cache/pip/http
# Dirname: 0
# Parent folder: ./.cache/pip/http
# Dirname: 3
# Parent folder: ./.cache/pip/http
# Dirname: 6
# Parent folder: ./.cache/pip/http
# Dirname: c
# Parent folder: ./.cache/pip/http
# Dirname: 9
# Parent folder: ./.cache/pip/http
# Dirname: d
# Parent folder: ./.cache/pip/http
# Dirname: b
# Parent folder: ./.cache/pip/http
# Dirname: e
# Parent folder: ./.cache/pip/http
# Dirname: 1
# Parent folder: ./.cache/pip/http
# Dirname: 5
# Parent folder: ./.cache/pip/http/a
# Dirname: 1
# Parent folder: ./.cache/pip/http/a
# Dirname: d
# Parent folder: ./.cache/pip/http/a
# Dirname: 9
# Parent folder: ./.cache/pip/http/a
# Dirname: f
# Parent folder: ./.cache/pip/http/a/1
# Dirname: 9
# Parent folder: ./.cache/pip/http/a/1/9
# Dirname: 5
# Parent folder: ./.cache/pip/http/a/1/9/5
# Dirname: 3
# Parent folder: ./.cache/pip/http/a/1/9/5/3
# Filename: a19537d3cf37c122db841d6fe4cd322bc10d1a558bb00d146b85cb9a
# Parent folder: ./.cache/pip/http/a/d
# Dirname: b
# Parent folder: ./.cache/pip/http/a/d/b
# Dirname: 3
# Parent folder: ./.cache/pip/http/a/d/b/3
# Dirname: d
# Parent folder: ./.cache/pip/http/a/d/b/3/d
# Filename: adb3d1ff0414d19ef98028b518f715b8e29084feffdc67f078513301
# Parent folder: ./.cache/pip/http/a/9
# Dirname: d
# Parent folder: ./.cache/pip/http/a/9/d
# Dirname: d
# Parent folder: ./.cache/pip/http/a/9/d/d
# Dirname: a
# Parent folder: ./.cache/pip/http/a/9/d/d/a
# Filename: a9ddae8587ecbaf986f1b2e53b9c0a0fc9deae3dd36b793bcd2fd672
# Parent folder: ./.cache/pip/http/a/f
# Dirname: 5
# Parent folder: ./.cache/pip/http/a/f/5
# Dirname: d
# Parent folder: ./.cache/pip/http/a/f/5/d
# Dirname: f
# Parent folder: ./.cache/pip/http/a/f/5/d/f
# Filename: af5dfde2b92cc9eb82c34ca7f95dd2524362f5e798e6f86c27b5c805
# Parent folder: ./.cache/pip/http/7
# Dirname: b
# Parent folder: ./.cache/pip/http/7
# Dirname: e
# Parent folder: ./.cache/pip/http/7
# Dirname: a
# Parent folder: ./.cache/pip/http/7
# Dirname: c
# Parent folder: ./.cache/pip/http/7
# Dirname: d
# Parent folder: ./.cache/pip/http/7
# Dirname: 0
# Parent folder: ./.cache/pip/http/7/b
# Dirname: b
# Parent folder: ./.cache/pip/http/7/b/b
# Dirname: e
# Parent folder: ./.cache/pip/http/7/b/b/e
# Dirname: 4
# Parent folder: ./.cache/pip/http/7/b/b/e/4
# Filename: 7bbe47980f49b7305d8ea0c017d6469e99eb42e5755ab9b3e555fab8
# Parent folder: ./.cache/pip/http/7/e
# Dirname: 4
# Parent folder: ./.cache/pip/http/7/e/4
# Dirname: 7
# Parent folder: ./.cache/pip/http/7/e/4/7
# Dirname: 2
# Parent folder: ./.cache/pip/http/7/e/4/7/2
# Filename: 7e472360855da81376e202ad4d8e87e21a0e9de62bd610676bb79e61
# Parent folder: ./.cache/pip/http/7/a
# Dirname: 5
# Parent folder: ./.cache/pip/http/7/a/5
# Dirname: f
# Parent folder: ./.cache/pip/http/7/a/5/f
# Dirname: 7
# Parent folder: ./.cache/pip/http/7/a/5/f/7
# Filename: 7a5f717e7b3fb99ec006f4d173aad55224eb063005c662c586ba0518
# Parent folder: ./.cache/pip/http/7/c
# Dirname: 4
# Parent folder: ./.cache/pip/http/7/c/4
# Dirname: b
# Parent folder: ./.cache/pip/http/7/c/4/b
# Dirname: 8
# Parent folder: ./.cache/pip/http/7/c/4/b/8
# Filename: 7c4b8a19f4f69494c22868b76649cd91120de17447e4ff71fb7a7f10
# Parent folder: ./.cache/pip/http/7/d
# Dirname: 9
# Parent folder: ./.cache/pip/http/7/d
# Dirname: 0
# Parent folder: ./.cache/pip/http/7/d/9
# Dirname: f
# Parent folder: ./.cache/pip/http/7/d/9/f
# Dirname: c
# Parent folder: ./.cache/pip/http/7/d/9/f/c
# Filename: 7d9fc72980162cfdee107d68ed91af7f0d17635944a2be45d02dcc8a
# Parent folder: ./.cache/pip/http/7/d/0
# Dirname: f
# Parent folder: ./.cache/pip/http/7/d/0/f
# Dirname: 5
# Parent folder: ./.cache/pip/http/7/d/0/f/5
# Filename: 7d0f5ac664601beb60d743febc6870898cbf636bdd54593cd7c902eb
# Parent folder: ./.cache/pip/http/7/0
# Dirname: 3
# Parent folder: ./.cache/pip/http/7/0/3
# Dirname: c
# Parent folder: ./.cache/pip/http/7/0/3/c
# Dirname: e
# Parent folder: ./.cache/pip/http/7/0/3/c/e
# Filename: 703cef51a5697a4b25ae1177ae64e9d42ecfc5d9b572a3b010907d29
# Parent folder: ./.cache/pip/http/4
# Dirname: 9
# Parent folder: ./.cache/pip/http/4
# Dirname: 7
# Parent folder: ./.cache/pip/http/4
# Dirname: 5
# Parent folder: ./.cache/pip/http/4
# Dirname: 1
# Parent folder: ./.cache/pip/http/4/9
# Dirname: a
# Parent folder: ./.cache/pip/http/4/9/a
# Dirname: 6
# Parent folder: ./.cache/pip/http/4/9/a/6
# Dirname: 5
# Parent folder: ./.cache/pip/http/4/9/a/6/5
# Filename: 49a65ef51069b1954617f8b76476ce09dc41c9efac53f4d81e1f5cf3
# Parent folder: ./.cache/pip/http/4/7
# Dirname: 4
# Parent folder: ./.cache/pip/http/4/7/4
# Dirname: 2
# Parent folder: ./.cache/pip/http/4/7/4/2
# Dirname: 3
# Parent folder: ./.cache/pip/http/4/7/4/2/3
# Filename: 47423f0ae230e783c554eaeb26f157ea109e72e7d6a451d050e926de
# Parent folder: ./.cache/pip/http/4/5
# Dirname: 9
# Parent folder: ./.cache/pip/http/4/5/9
# Dirname: 7
# Parent folder: ./.cache/pip/http/4/5/9/7
# Dirname: 6
# Parent folder: ./.cache/pip/http/4/5/9/7/6
# Filename: 45976c194ebb9180bf7410d422bcad653ce13bcb64dda0d07d72b09d
# Parent folder: ./.cache/pip/http/4/1
# Dirname: a
# Parent folder: ./.cache/pip/http/4/1/a
# Dirname: 4
# Parent folder: ./.cache/pip/http/4/1/a/4
# Dirname: a
# Parent folder: ./.cache/pip/http/4/1/a/4/a
# Filename: 41a4a5b4d08d682c256c42188a3386c88748bf23a52b7c7ccc3a01f0
# Parent folder: ./.cache/pip/http/8
# Dirname: 8
# Parent folder: ./.cache/pip/http/8
# Dirname: a
# Parent folder: ./.cache/pip/http/8
# Dirname: 2
# Parent folder: ./.cache/pip/http/8/8
# Dirname: 5
# Parent folder: ./.cache/pip/http/8/8/5
# Dirname: 7
# Parent folder: ./.cache/pip/http/8/8/5/7
# Dirname: 5
# Parent folder: ./.cache/pip/http/8/8/5/7/5
# Filename: 885756dbd26b12f0ce040346860f98e8a505a2811209b64c6065caf5
# Parent folder: ./.cache/pip/http/8/a
# Dirname: 5
# Parent folder: ./.cache/pip/http/8/a/5
# Dirname: b
# Parent folder: ./.cache/pip/http/8/a/5/b
# Dirname: c
# Parent folder: ./.cache/pip/http/8/a/5/b/c
# Filename: 8a5bc05463e51d20ad06ed247ae6d9eae9268c9cccc2c5d729df74f1
# Parent folder: ./.cache/pip/http/8/2
# Dirname: c
# Parent folder: ./.cache/pip/http/8/2/c
# Dirname: b
# Parent folder: ./.cache/pip/http/8/2/c/b
# Dirname: 6
# Parent folder: ./.cache/pip/http/8/2/c/b/6
# Filename: 82cb6a7ab0f2277a7c78261aeaa1f2c561796b9321bfd8c2937c5fa0
# Parent folder: ./.cache/pip/http/2
# Dirname: 4
# Parent folder: ./.cache/pip/http/2
# Dirname: d
# Parent folder: ./.cache/pip/http/2
# Dirname: c
# Parent folder: ./.cache/pip/http/2
# Dirname: 1
# Parent folder: ./.cache/pip/http/2
# Dirname: e
# Parent folder: ./.cache/pip/http/2/4
# Dirname: 9
# Parent folder: ./.cache/pip/http/2/4/9
# Dirname: 9
# Parent folder: ./.cache/pip/http/2/4/9/9
# Dirname: 6
# Parent folder: ./.cache/pip/http/2/4/9/9/6
# Filename: 249966c7f1e7970eeae0088cdcd48fa18209582a788c44b34dc549ce
# Parent folder: ./.cache/pip/http/2/d
# Dirname: a
# Parent folder: ./.cache/pip/http/2/d/a
# Dirname: f
# Parent folder: ./.cache/pip/http/2/d/a/f
# Dirname: e
# Parent folder: ./.cache/pip/http/2/d/a/f/e
# Filename: 2dafea6c0f1b47eeb64a6589a2b29e655db43127283a1f06acd54ebe
# Parent folder: ./.cache/pip/http/2/c
# Dirname: 6
# Parent folder: ./.cache/pip/http/2/c/6
# Dirname: 8
# Parent folder: ./.cache/pip/http/2/c/6/8
# Dirname: f
# Parent folder: ./.cache/pip/http/2/c/6/8/f
# Filename: 2c68f5f22a2976f4d6ba1cdc1f6849b51d0a96a9b75a406470bd408a
# Parent folder: ./.cache/pip/http/2/1
# Dirname: a
# Parent folder: ./.cache/pip/http/2/1/a
# Dirname: 5
# Parent folder: ./.cache/pip/http/2/1/a/5
# Dirname: 4
# Parent folder: ./.cache/pip/http/2/1/a/5/4
# Filename: 21a54f6d02f3dded648f189d74b995474e64b681feca0efbbd8a8de7
# Parent folder: ./.cache/pip/http/2/e
# Dirname: d
# Parent folder: ./.cache/pip/http/2/e/d
# Dirname: d
# Parent folder: ./.cache/pip/http/2/e/d/d
# Dirname: d
# Parent folder: ./.cache/pip/http/2/e/d/d/d
# Filename: 2eddd0827b112690d28dfeb527dc0f9b179fa8346ff835ee976a74f9
# Parent folder: ./.cache/pip/http/f
# Dirname: d
# Parent folder: ./.cache/pip/http/f
# Dirname: 5
# Parent folder: ./.cache/pip/http/f
# Dirname: 3
# Parent folder: ./.cache/pip/http/f
# Dirname: 8
# Parent folder: ./.cache/pip/http/f
# Dirname: 1
# Parent folder: ./.cache/pip/http/f/d
# Dirname: d
# Parent folder: ./.cache/pip/http/f/d/d
# Dirname: d
# Parent folder: ./.cache/pip/http/f/d/d/d
# Dirname: d
# Parent folder: ./.cache/pip/http/f/d/d/d/d
# Filename: fdddd5c88e6ad5c56b7bcbbfa24f3a45e2dde4ad6999ba6116fb9155
# Parent folder: ./.cache/pip/http/f/5
# Dirname: 7
# Parent folder: ./.cache/pip/http/f/5/7
# Dirname: 7
# Parent folder: ./.cache/pip/http/f/5/7/7
# Dirname: 8
# Parent folder: ./.cache/pip/http/f/5/7/7/8
# Filename: f577813f4ca515a35041c12b0f4316cdc549f31b0b105426fc1bf4c8
# Parent folder: ./.cache/pip/http/f/3
# Dirname: 0
# Parent folder: ./.cache/pip/http/f/3/0
# Dirname: 0
# Parent folder: ./.cache/pip/http/f/3/0/0
# Dirname: c
# Parent folder: ./.cache/pip/http/f/3/0/0/c
# Filename: f300c050a103cf0829e18de8180af0b716f6d18b4bd9534e24100cf8
# Parent folder: ./.cache/pip/http/f/8
# Dirname: 8
# Parent folder: ./.cache/pip/http/f/8/8
# Dirname: d
# Parent folder: ./.cache/pip/http/f/8/8/d
# Dirname: 5
# Parent folder: ./.cache/pip/http/f/8/8/d/5
# Filename: f88d5ec8adc46a5aaa793767420be12dc11319ce92efa7f219cae1d5
# Parent folder: ./.cache/pip/http/f/1
# Dirname: 3
# Parent folder: ./.cache/pip/http/f/1/3
# Dirname: 1
# Parent folder: ./.cache/pip/http/f/1/3/1
# Dirname: 6
# Parent folder: ./.cache/pip/http/f/1/3/1/6
# Filename: f1316923807644dbbc053df2e36d7eac1efae1c3bf48ce10ef488c7e
# Parent folder: ./.cache/pip/http/0
# Dirname: 6
# Parent folder: ./.cache/pip/http/0
# Dirname: 2
# Parent folder: ./.cache/pip/http/0
# Dirname: e
# Parent folder: ./.cache/pip/http/0
# Dirname: 4
# Parent folder: ./.cache/pip/http/0
# Dirname: a
# Parent folder: ./.cache/pip/http/0
# Dirname: b
# Parent folder: ./.cache/pip/http/0/6
# Dirname: 7
# Parent folder: ./.cache/pip/http/0/6
# Dirname: a
# Parent folder: ./.cache/pip/http/0/6/7
# Dirname: 2
# Parent folder: ./.cache/pip/http/0/6/7/2
# Dirname: 6
# Parent folder: ./.cache/pip/http/0/6/7/2/6
# Filename: 06726d442b7e33afe35f1740674b6dee72357a95eef3aca0ef7abf21
# Parent folder: ./.cache/pip/http/0/6/a
# Dirname: 1
# Parent folder: ./.cache/pip/http/0/6/a/1
# Dirname: 0
# Parent folder: ./.cache/pip/http/0/6/a/1/0
# Filename: 06a10a01993b98a46b24126de4370c3ed430c734a40d6ac34065ddcf
# Parent folder: ./.cache/pip/http/0/2
# Dirname: e
# Parent folder: ./.cache/pip/http/0/2/e
# Dirname: a
# Parent folder: ./.cache/pip/http/0/2/e/a
# Dirname: 3
# Parent folder: ./.cache/pip/http/0/2/e/a/3
# Filename: 02ea3a40bec709fb2e3011abf56d9ff0e8a057e522b64b520bfc74fe
# Parent folder: ./.cache/pip/http/0/e
# Dirname: b
# Parent folder: ./.cache/pip/http/0/e/b
# Dirname: c
# Parent folder: ./.cache/pip/http/0/e/b/c
# Dirname: b
# Parent folder: ./.cache/pip/http/0/e/b/c/b
# Filename: 0ebcbab95b2ba9f500489affe27a77c26b1bdeffc3b2a268c9c2879b
# Parent folder: ./.cache/pip/http/0/4
# Dirname: 4
# Parent folder: ./.cache/pip/http/0/4/4
# Dirname: 5
# Parent folder: ./.cache/pip/http/0/4/4/5
# Dirname: 2
# Parent folder: ./.cache/pip/http/0/4/4/5/2
# Filename: 04452fdd540f45013491158424fe83c068e5194fd20f3c7d05ab29cf
# Parent folder: ./.cache/pip/http/0/a
# Dirname: 6
# Parent folder: ./.cache/pip/http/0/a/6
# Dirname: 9
# Parent folder: ./.cache/pip/http/0/a/6/9
# Dirname: 0
# Parent folder: ./.cache/pip/http/0/a/6/9/0
# Filename: 0a690ae203cfcecc7cd36937c2c67e726a0b8c17695217fa14b6dd6f
# Parent folder: ./.cache/pip/http/0/b
# Dirname: e
# Parent folder: ./.cache/pip/http/0/b/e
# Dirname: 7
# Parent folder: ./.cache/pip/http/0/b/e/7
# Dirname: d
# Parent folder: ./.cache/pip/http/0/b/e/7/d
# Filename: 0be7dbf34ae66fe142acfa907e4ced64be83a9e379f0b599b4fec630
# Parent folder: ./.cache/pip/http/3
# Dirname: 7
# Parent folder: ./.cache/pip/http/3
# Dirname: 3
# Parent folder: ./.cache/pip/http/3
# Dirname: 4
# Parent folder: ./.cache/pip/http/3
# Dirname: 1
# Parent folder: ./.cache/pip/http/3
# Dirname: b
# Parent folder: ./.cache/pip/http/3
# Dirname: e
# Parent folder: ./.cache/pip/http/3/7
# Dirname: 4
# Parent folder: ./.cache/pip/http/3/7
# Dirname: 6
# Parent folder: ./.cache/pip/http/3/7/4
# Dirname: a
# Parent folder: ./.cache/pip/http/3/7/4/a
# Dirname: e
# Parent folder: ./.cache/pip/http/3/7/4/a/e
# Filename: 374aeb1cb4b0c64d7379118b73acd71d5b5831b27b95883dd761d008
# Parent folder: ./.cache/pip/http/3/7/6
# Dirname: e
# Parent folder: ./.cache/pip/http/3/7/6/e
# Dirname: 4
# Parent folder: ./.cache/pip/http/3/7/6/e/4
# Filename: 376e43c12054af0312545d3671391c7ba06b7fb9a99e035fe29e0bc7
# Parent folder: ./.cache/pip/http/3/3
# Dirname: d
# Parent folder: ./.cache/pip/http/3/3
# Dirname: e
# Parent folder: ./.cache/pip/http/3/3/d
# Dirname: a
# Parent folder: ./.cache/pip/http/3/3/d/a
# Dirname: e
# Parent folder: ./.cache/pip/http/3/3/d/a/e
# Filename: 33dae1d4935615ec370738b58d2005654207defc4513f12803aeb60e
# Parent folder: ./.cache/pip/http/3/3/e
# Dirname: d
# Parent folder: ./.cache/pip/http/3/3/e/d
# Dirname: f
# Parent folder: ./.cache/pip/http/3/3/e/d/f
# Filename: 33edfdc631388d50e17fdfc77f6245d6a716f94b1333842b4cce6055
# Parent folder: ./.cache/pip/http/3/4
# Dirname: 9
# Parent folder: ./.cache/pip/http/3/4/9
# Dirname: b
# Parent folder: ./.cache/pip/http/3/4/9/b
# Dirname: 3
# Parent folder: ./.cache/pip/http/3/4/9/b/3
# Filename: 349b33f3b41e3f3f3661fc4a54ab9d2efdf6ea1f7d34d81a9ec7eacf
# Parent folder: ./.cache/pip/http/3/1
# Dirname: 5
# Parent folder: ./.cache/pip/http/3/1/5
# Dirname: b
# Parent folder: ./.cache/pip/http/3/1/5/b
# Dirname: d
# Parent folder: ./.cache/pip/http/3/1/5/b/d
# Filename: 315bd5994915d999cc934902f11d8d89b7bce4fc77ed43b9a66f4aad
# Parent folder: ./.cache/pip/http/3/b
# Dirname: 4
# Parent folder: ./.cache/pip/http/3/b/4
# Dirname: 5
# Parent folder: ./.cache/pip/http/3/b/4/5
# Dirname: 7
# Parent folder: ./.cache/pip/http/3/b/4/5/7
# Filename: 3b45732363e9583efd55b602b7f827c3b46e770223a2f00f06f4d23e
# Parent folder: ./.cache/pip/http/3/e
# Dirname: 9
# Parent folder: ./.cache/pip/http/3/e/9
# Dirname: a
# Parent folder: ./.cache/pip/http/3/e/9/a
# Dirname: 4
# Parent folder: ./.cache/pip/http/3/e/9/a/4
# Filename: 3e9a4e7f56493e9f06407dbc32afae529f65c7ec2e8742451dcc4271
# Parent folder: ./.cache/pip/http/6
# Dirname: 1
# Parent folder: ./.cache/pip/http/6
# Dirname: 2
# Parent folder: ./.cache/pip/http/6
# Dirname: 9
# Parent folder: ./.cache/pip/http/6
# Dirname: d
# Parent folder: ./.cache/pip/http/6/1
# Dirname: 4
# Parent folder: ./.cache/pip/http/6/1/4
# Dirname: f
# Parent folder: ./.cache/pip/http/6/1/4/f
# Dirname: 4
# Parent folder: ./.cache/pip/http/6/1/4/f/4
# Filename: 614f46c6d1c16fa5b0800dfd0497e41c5b320e16ee8c9d943d4dd341
# Parent folder: ./.cache/pip/http/6/2
# Dirname: 7
# Parent folder: ./.cache/pip/http/6/2/7
# Dirname: 1
# Parent folder: ./.cache/pip/http/6/2/7/1
# Dirname: 9
# Parent folder: ./.cache/pip/http/6/2/7/1/9
# Filename: 62719f5759a540f7f3bc6a016369173df92785cae2e0fc64501961ee
# Parent folder: ./.cache/pip/http/6/9
# Dirname: 4
# Parent folder: ./.cache/pip/http/6/9/4
# Dirname: e
# Parent folder: ./.cache/pip/http/6/9/4/e
# Dirname: 2
# Parent folder: ./.cache/pip/http/6/9/4/e/2
# Filename: 694e2bf3f7b9fc73e1690dea790651bcdc6cc58d6887ec476cdbbc4c
# Parent folder: ./.cache/pip/http/6/d
# Dirname: 0
# Parent folder: ./.cache/pip/http/6/d/0
# Dirname: d
# Parent folder: ./.cache/pip/http/6/d/0/d
# Dirname: 6
# Parent folder: ./.cache/pip/http/6/d/0/d/6
# Filename: 6d0d6c64f2978576072bff7577001f7e840689aefb879244125df04e
# Parent folder: ./.cache/pip/http/c
# Dirname: 5
# Parent folder: ./.cache/pip/http/c
# Dirname: a
# Parent folder: ./.cache/pip/http/c
# Dirname: 9
# Parent folder: ./.cache/pip/http/c
# Dirname: c
# Parent folder: ./.cache/pip/http/c
# Dirname: 6
# Parent folder: ./.cache/pip/http/c
# Dirname: f
# Parent folder: ./.cache/pip/http/c
# Dirname: 0
# Parent folder: ./.cache/pip/http/c
# Dirname: 4
# Parent folder: ./.cache/pip/http/c
# Dirname: b
# Parent folder: ./.cache/pip/http/c/5
# Dirname: f
# Parent folder: ./.cache/pip/http/c/5
# Dirname: 4
# Parent folder: ./.cache/pip/http/c/5/f
# Dirname: 2
# Parent folder: ./.cache/pip/http/c/5/f/2
# Dirname: 1
# Parent folder: ./.cache/pip/http/c/5/f/2/1
# Filename: c5f210f1b8727586bb2f0e2211ce6f322293c8aa302785e182811194
# Parent folder: ./.cache/pip/http/c/5/4
# Dirname: 0
# Parent folder: ./.cache/pip/http/c/5/4/0
# Dirname: 3
# Parent folder: ./.cache/pip/http/c/5/4/0/3
# Filename: c5403a101bbaf526810b4c472004bc3b03b96b7c8118e06c7a081e63
# Parent folder: ./.cache/pip/http/c/a
# Dirname: 4
# Parent folder: ./.cache/pip/http/c/a
# Dirname: f
# Parent folder: ./.cache/pip/http/c/a/4
# Dirname: 0
# Parent folder: ./.cache/pip/http/c/a/4/0
# Dirname: 5
# Parent folder: ./.cache/pip/http/c/a/4/0/5
# Filename: ca40521d6f4ca2bc510659d13a3cff56d7241103db5d1e645bc10f8f
# Parent folder: ./.cache/pip/http/c/a/f
# Dirname: c
# Parent folder: ./.cache/pip/http/c/a/f/c
# Dirname: 3
# Parent folder: ./.cache/pip/http/c/a/f/c/3
# Filename: cafc393f20e1ce4f939952e7285962151bec36eeb5b1b7b65449a327
# Parent folder: ./.cache/pip/http/c/9
# Dirname: 1
# Parent folder: ./.cache/pip/http/c/9/1
# Dirname: f
# Parent folder: ./.cache/pip/http/c/9/1/f
# Dirname: 2
# Parent folder: ./.cache/pip/http/c/9/1/f/2
# Filename: c91f2e41337665457740aa256c527d2526390279f8c0d22dbb82a31c
# Parent folder: ./.cache/pip/http/c/c
# Dirname: 9
# Parent folder: ./.cache/pip/http/c/c/9
# Dirname: 0
# Parent folder: ./.cache/pip/http/c/c/9/0
# Dirname: 2
# Parent folder: ./.cache/pip/http/c/c/9/0/2
# Filename: cc902747510a1521fdae0cf35c9f9ba95bc0b0b19cddc266bccf83cb
# Parent folder: ./.cache/pip/http/c/6
# Dirname: d
# Parent folder: ./.cache/pip/http/c/6/d
# Dirname: a
# Parent folder: ./.cache/pip/http/c/6/d/a
# Dirname: 4
# Parent folder: ./.cache/pip/http/c/6/d/a/4
# Filename: c6da4e42a35803426c2ddc3fd67c156e0afccabbea63254936d6f983
# Parent folder: ./.cache/pip/http/c/f
# Dirname: 0
# Parent folder: ./.cache/pip/http/c/f/0
# Dirname: 3
# Parent folder: ./.cache/pip/http/c/f/0/3
# Dirname: 3
# Parent folder: ./.cache/pip/http/c/f/0/3/3
# Filename: cf03377162fd071e75250e4827adf3bc208ef008cb9e4caa71d95660
# Parent folder: ./.cache/pip/http/c/0
# Dirname: 4
# Parent folder: ./.cache/pip/http/c/0/4
# Dirname: 0
# Parent folder: ./.cache/pip/http/c/0/4/0
# Dirname: 0
# Parent folder: ./.cache/pip/http/c/0/4/0/0
# Filename: c0400f4849a16bb7ec1db13ba6d964327b0869995ab53c54f6668654
# Parent folder: ./.cache/pip/http/c/4
# Dirname: d
# Parent folder: ./.cache/pip/http/c/4/d
# Dirname: d
# Parent folder: ./.cache/pip/http/c/4/d/d
# Dirname: 7
# Parent folder: ./.cache/pip/http/c/4/d/d/7
# Filename: c4dd73c6678ba2c4ade222340ae4a5c55ad04a22b372d0240bccbf61
# Parent folder: ./.cache/pip/http/c/b
# Dirname: 5
# Parent folder: ./.cache/pip/http/c/b/5
# Dirname: 2
# Parent folder: ./.cache/pip/http/c/b/5/2
# Dirname: a
# Parent folder: ./.cache/pip/http/c/b/5/2/a
# Filename: cb52a2d86b549893dbebd3c41cb632b74900e6546f238508e1029e00
# Parent folder: ./.cache/pip/http/9
# Dirname: d
# Parent folder: ./.cache/pip/http/9
# Dirname: 1
# Parent folder: ./.cache/pip/http/9
# Dirname: 3
# Parent folder: ./.cache/pip/http/9
# Dirname: 4
# Parent folder: ./.cache/pip/http/9
# Dirname: 7
# Parent folder: ./.cache/pip/http/9
# Dirname: f
# Parent folder: ./.cache/pip/http/9
# Dirname: 0
# Parent folder: ./.cache/pip/http/9
# Dirname: a
# Parent folder: ./.cache/pip/http/9/d
# Dirname: 1
# Parent folder: ./.cache/pip/http/9/d
# Dirname: 3
# Parent folder: ./.cache/pip/http/9/d/1
# Dirname: b
# Parent folder: ./.cache/pip/http/9/d/1/b
# Dirname: 5
# Parent folder: ./.cache/pip/http/9/d/1/b/5
# Filename: 9d1b5609ebe8e758b25afac0a3ddcc4e7db01242a2daf131637ef728
# Parent folder: ./.cache/pip/http/9/d/3
# Dirname: 2
# Parent folder: ./.cache/pip/http/9/d/3/2
# Dirname: 5
# Parent folder: ./.cache/pip/http/9/d/3/2/5
# Filename: 9d325a184c63757759fe63c775f86e4e322de1d9e56fbf02857314be
# Parent folder: ./.cache/pip/http/9/1
# Dirname: 5
# Parent folder: ./.cache/pip/http/9/1/5
# Dirname: 2
# Parent folder: ./.cache/pip/http/9/1/5/2
# Dirname: 1
# Parent folder: ./.cache/pip/http/9/1/5/2/1
# Filename: 91521437e91f6e824e63a08745382f22bf2731a80b1c2378634f066c
# Parent folder: ./.cache/pip/http/9/3
# Dirname: 4
# Parent folder: ./.cache/pip/http/9/3/4
# Dirname: 2
# Parent folder: ./.cache/pip/http/9/3/4/2
# Dirname: c
# Parent folder: ./.cache/pip/http/9/3/4/2/c
# Filename: 9342ccd26cbebf3b7f292e682bc1a9e8141b62c8c93481f8de30cf71
# Parent folder: ./.cache/pip/http/9/4
# Dirname: b
# Parent folder: ./.cache/pip/http/9/4
# Dirname: 5
# Parent folder: ./.cache/pip/http/9/4/b
# Dirname: 6
# Parent folder: ./.cache/pip/http/9/4/b/6
# Dirname: 7
# Parent folder: ./.cache/pip/http/9/4/b/6/7
# Filename: 94b67f200f2d3b65aa348435c1a04e0a7417fd6079cdee6febd0d565
# Parent folder: ./.cache/pip/http/9/4/5
# Dirname: 2
# Parent folder: ./.cache/pip/http/9/4/5/2
# Dirname: 4
# Parent folder: ./.cache/pip/http/9/4/5/2/4
# Filename: 9452417670b2e75527d793717779fce5d54e5f21adb3344c273876fa
# Parent folder: ./.cache/pip/http/9/7
# Dirname: 2
# Parent folder: ./.cache/pip/http/9/7/2
# Dirname: 3
# Parent folder: ./.cache/pip/http/9/7/2/3
# Dirname: f
# Parent folder: ./.cache/pip/http/9/7/2/3/f
# Filename: 9723f956c2832f0bf7a0b916be4cb31c77752847964e667e66c6bd97
# Parent folder: ./.cache/pip/http/9/f
# Dirname: 9
# Parent folder: ./.cache/pip/http/9/f/9
# Dirname: 3
# Parent folder: ./.cache/pip/http/9/f/9/3
# Dirname: 3
# Parent folder: ./.cache/pip/http/9/f/9/3/3
# Filename: 9f93306d7b672475999e1ccb003ed535876b07060341d71f2c054af0
# Parent folder: ./.cache/pip/http/9/0
# Dirname: 9
# Parent folder: ./.cache/pip/http/9/0/9
# Dirname: 8
# Parent folder: ./.cache/pip/http/9/0/9/8
# Dirname: 1
# Parent folder: ./.cache/pip/http/9/0/9/8/1
# Filename: 909813eafe1e02e4267e463ae579003c4bd8475678499490a5b2df98
# Parent folder: ./.cache/pip/http/9/a
# Dirname: 7
# Parent folder: ./.cache/pip/http/9/a/7
# Dirname: 9
# Parent folder: ./.cache/pip/http/9/a/7/9
# Dirname: 1
# Parent folder: ./.cache/pip/http/9/a/7/9/1
# Filename: 9a7919632a627df3dda5a9d49c83ec2b18b45cc7e8f1f731bf5b7471
# Parent folder: ./.cache/pip/http/d
# Dirname: 9
# Parent folder: ./.cache/pip/http/d
# Dirname: 1
# Parent folder: ./.cache/pip/http/d
# Dirname: d
# Parent folder: ./.cache/pip/http/d
# Dirname: e
# Parent folder: ./.cache/pip/http/d/9
# Dirname: f
# Parent folder: ./.cache/pip/http/d/9/f
# Dirname: f
# Parent folder: ./.cache/pip/http/d/9/f/f
# Dirname: e
# Parent folder: ./.cache/pip/http/d/9/f/f/e
# Filename: d9ffebdb626d3816fcbf1004c9d0f809f13da7f2d0bbe1c5cc515653
# Parent folder: ./.cache/pip/http/d/1
# Dirname: 0
# Parent folder: ./.cache/pip/http/d/1
# Dirname: 4
# Parent folder: ./.cache/pip/http/d/1/0
# Dirname: 2
# Parent folder: ./.cache/pip/http/d/1/0/2
# Dirname: b
# Parent folder: ./.cache/pip/http/d/1/0/2/b
# Filename: d102b637fab87b121bcddb6b847b89040d28ea8a4db98c2762f97319
# Parent folder: ./.cache/pip/http/d/1/4
# Dirname: 8
# Parent folder: ./.cache/pip/http/d/1/4/8
# Dirname: 1
# Parent folder: ./.cache/pip/http/d/1/4/8/1
# Filename: d148131676feda3b83355988943658476e598fa3dff07ddf0513e749
# Parent folder: ./.cache/pip/http/d/d
# Dirname: 1
# Parent folder: ./.cache/pip/http/d/d/1
# Dirname: e
# Parent folder: ./.cache/pip/http/d/d/1/e
# Dirname: b
# Parent folder: ./.cache/pip/http/d/d/1/e/b
# Filename: dd1eb495fa45c2e8e78dcc14147d98c3b57a91598c6c58a747dc7202
# Parent folder: ./.cache/pip/http/d/e
# Dirname: 8
# Parent folder: ./.cache/pip/http/d/e/8
# Dirname: 7
# Parent folder: ./.cache/pip/http/d/e/8/7
# Dirname: e
# Parent folder: ./.cache/pip/http/d/e/8/7/e
# Filename: de87eadb651e0add599fefb34cf36a9ced3fef4608f3f5d9bc75fd1d
# Parent folder: ./.cache/pip/http/b
# Dirname: d
# Parent folder: ./.cache/pip/http/b
# Dirname: 8
# Parent folder: ./.cache/pip/http/b
# Dirname: f
# Parent folder: ./.cache/pip/http/b
# Dirname: 6
# Parent folder: ./.cache/pip/http/b/d
# Dirname: 7
# Parent folder: ./.cache/pip/http/b/d/7
# Dirname: 4
# Parent folder: ./.cache/pip/http/b/d/7/4
# Dirname: f
# Parent folder: ./.cache/pip/http/b/d/7/4/f
# Filename: bd74fad1c77fdca7ab139a372ffb69f200b19bc0f15093980e304e25
# Parent folder: ./.cache/pip/http/b/8
# Dirname: b
# Parent folder: ./.cache/pip/http/b/8
# Dirname: 6
# Parent folder: ./.cache/pip/http/b/8/b
# Dirname: f
# Parent folder: ./.cache/pip/http/b/8/b/f
# Dirname: 4
# Parent folder: ./.cache/pip/http/b/8/b/f/4
# Filename: b8bf4a44dbb1c5e59b2500975b68a4301d11f85878b612151a649c3d
# Parent folder: ./.cache/pip/http/b/8/6
# Dirname: 2
# Parent folder: ./.cache/pip/http/b/8/6/2
# Dirname: 6
# Parent folder: ./.cache/pip/http/b/8/6/2/6
# Filename: b862637a242a4033f1ba3be874e038f3a95ab29277da4c878f7c162d
# Parent folder: ./.cache/pip/http/b/f
# Dirname: f
# Parent folder: ./.cache/pip/http/b/f
# Dirname: 2
# Parent folder: ./.cache/pip/http/b/f/f
# Dirname: 2
# Parent folder: ./.cache/pip/http/b/f/f/2
# Dirname: f
# Parent folder: ./.cache/pip/http/b/f/f/2/f
# Filename: bff2fa3aacecfd9e684a43ba9fdff0584b7c53dc6320af0ae92ff592
# Parent folder: ./.cache/pip/http/b/f/2
# Dirname: 7
# Parent folder: ./.cache/pip/http/b/f/2/7
# Dirname: 7
# Parent folder: ./.cache/pip/http/b/f/2/7/7
# Filename: bf277bedcc99e3453379c4c0cbd0cb39994f445f21dff38b0a607a95
# Parent folder: ./.cache/pip/http/b/6
# Dirname: f
# Parent folder: ./.cache/pip/http/b/6/f
# Dirname: 2
# Parent folder: ./.cache/pip/http/b/6/f/2
# Dirname: f
# Parent folder: ./.cache/pip/http/b/6/f/2/f
# Filename: b6f2f99998f2235742a8b3a3b2798623d50d354eed1c47aa3c651229
# Parent folder: ./.cache/pip/http/e
# Dirname: 1
# Parent folder: ./.cache/pip/http/e
# Dirname: 8
# Parent folder: ./.cache/pip/http/e
# Dirname: 9
# Parent folder: ./.cache/pip/http/e
# Dirname: 0
# Parent folder: ./.cache/pip/http/e
# Dirname: 4
# Parent folder: ./.cache/pip/http/e
# Dirname: a
# Parent folder: ./.cache/pip/http/e
# Dirname: 2
# Parent folder: ./.cache/pip/http/e/1
# Dirname: 3
# Parent folder: ./.cache/pip/http/e/1
# Dirname: a
# Parent folder: ./.cache/pip/http/e/1/3
# Dirname: 7
# Parent folder: ./.cache/pip/http/e/1/3/7
# Dirname: 4
# Parent folder: ./.cache/pip/http/e/1/3/7/4
# Filename: e1374613b89e5ef99ce404da422d6e391c381cb3e690748f4344db03
# Parent folder: ./.cache/pip/http/e/1/a
# Dirname: 1
# Parent folder: ./.cache/pip/http/e/1/a/1
# Dirname: 0
# Parent folder: ./.cache/pip/http/e/1/a/1/0
# Filename: e1a102a58d5f97b4d2a7ffd62157f43e68a5808f81e4779f2eb95e89
# Parent folder: ./.cache/pip/http/e/8
# Dirname: d
# Parent folder: ./.cache/pip/http/e/8
# Dirname: 9
# Parent folder: ./.cache/pip/http/e/8
# Dirname: b
# Parent folder: ./.cache/pip/http/e/8/d
# Dirname: 2
# Parent folder: ./.cache/pip/http/e/8/d/2
# Dirname: 0
# Parent folder: ./.cache/pip/http/e/8/d/2/0
# Filename: e8d2080a1e81f809dbe2a0d6f7f53c2d594586c3319a4e0a904b0bcc
# Parent folder: ./.cache/pip/http/e/8/9
# Dirname: a
# Parent folder: ./.cache/pip/http/e/8/9/a
# Dirname: 9
# Parent folder: ./.cache/pip/http/e/8/9/a/9
# Filename: e89a917152afa9d03f9ed4a9112948c51212ede7c1d25bad1c96fdf0
# Parent folder: ./.cache/pip/http/e/8/b
# Dirname: a
# Parent folder: ./.cache/pip/http/e/8/b/a
# Dirname: 7
# Parent folder: ./.cache/pip/http/e/8/b/a/7
# Filename: e8ba792a06609c54bb3f67764540fec0e79947cc8643af52c84eda38
# Parent folder: ./.cache/pip/http/e/9
# Dirname: d
# Parent folder: ./.cache/pip/http/e/9/d
# Dirname: c
# Parent folder: ./.cache/pip/http/e/9/d/c
# Dirname: e
# Parent folder: ./.cache/pip/http/e/9/d/c/e
# Filename: e9dce085b25e5903438c967bf7dd70971ada620c696d033ce9ace2c7
# Parent folder: ./.cache/pip/http/e/0
# Dirname: 1
# Parent folder: ./.cache/pip/http/e/0
# Dirname: 7
# Parent folder: ./.cache/pip/http/e/0/1
# Dirname: d
# Parent folder: ./.cache/pip/http/e/0/1/d
# Dirname: 9
# Parent folder: ./.cache/pip/http/e/0/1/d/9
# Filename: e01d9ae49e6adc6646c9f2136ef162187b48cf0195db7098f71cd7e3
# Parent folder: ./.cache/pip/http/e/0/7
# Dirname: 4
# Parent folder: ./.cache/pip/http/e/0/7/4
# Dirname: 5
# Parent folder: ./.cache/pip/http/e/0/7/4/5
# Filename: e0745285a6530dadea729697d461e25795124a34057dfd41d504e820
# Parent folder: ./.cache/pip/http/e/4
# Dirname: 9
# Parent folder: ./.cache/pip/http/e/4/9
# Dirname: b
# Parent folder: ./.cache/pip/http/e/4/9/b
# Dirname: 3
# Parent folder: ./.cache/pip/http/e/4/9/b/3
# Filename: e49b3d01fb145d041b689aea7844c49e6bddadb7638cecbf2a338d26
# Parent folder: ./.cache/pip/http/e/a
# Dirname: b
# Parent folder: ./.cache/pip/http/e/a/b
# Dirname: 2
# Parent folder: ./.cache/pip/http/e/a/b/2
# Dirname: 2
# Parent folder: ./.cache/pip/http/e/a/b/2/2
# Filename: eab22979faa01702a04306ba32f2d23990d4169521769f50f7291975
# Parent folder: ./.cache/pip/http/e/2
# Dirname: a
# Parent folder: ./.cache/pip/http/e/2/a
# Dirname: 4
# Parent folder: ./.cache/pip/http/e/2/a/4
# Dirname: 1
# Parent folder: ./.cache/pip/http/e/2/a/4/1
# Filename: e2a4183dd1728c1c56548cb34b9f1e0eeee647b05216ea8ddb390c7e
# Parent folder: ./.cache/pip/http/1
# Dirname: f
# Parent folder: ./.cache/pip/http/1
# Dirname: 1
# Parent folder: ./.cache/pip/http/1
# Dirname: a
# Parent folder: ./.cache/pip/http/1/f
# Dirname: c
# Parent folder: ./.cache/pip/http/1/f
# Dirname: 3
# Parent folder: ./.cache/pip/http/1/f/c
# Dirname: 9
# Parent folder: ./.cache/pip/http/1/f/c/9
# Dirname: c
# Parent folder: ./.cache/pip/http/1/f/c/9/c
# Filename: 1fc9c14cde8be2d162b8d36abfbcca63d0c1bfdd4566b02dc638beda
# Parent folder: ./.cache/pip/http/1/f/3
# Dirname: a
# Parent folder: ./.cache/pip/http/1/f/3/a
# Dirname: 0
# Parent folder: ./.cache/pip/http/1/f/3/a/0
# Filename: 1f3a010a7cc3ca64eac10d62d9f15870c702fc5a0cf7712c5ae43c10
# Parent folder: ./.cache/pip/http/1/1
# Dirname: 1
# Parent folder: ./.cache/pip/http/1/1/1
# Dirname: 5
# Parent folder: ./.cache/pip/http/1/1/1/5
# Dirname: a
# Parent folder: ./.cache/pip/http/1/1/1/5/a
# Filename: 1115a0b767c1f0cd9a958e2b6626732254f5de91c084b9dbd27a4951
# Parent folder: ./.cache/pip/http/1/a
# Dirname: a
# Parent folder: ./.cache/pip/http/1/a/a
# Dirname: f
# Parent folder: ./.cache/pip/http/1/a/a/f
# Dirname: 1
# Parent folder: ./.cache/pip/http/1/a/a/f/1
# Filename: 1aaf12502d9d2700532b5c7786558a9bfb4d409422398ffa270ae51d
# Parent folder: ./.cache/pip/http/5
# Dirname: e
# Parent folder: ./.cache/pip/http/5
# Dirname: f
# Parent folder: ./.cache/pip/http/5/e
# Dirname: 1
# Parent folder: ./.cache/pip/http/5/e/1
# Dirname: 5
# Parent folder: ./.cache/pip/http/5/e/1/5
# Dirname: 6
# Parent folder: ./.cache/pip/http/5/e/1/5/6
# Filename: 5e1566c3cd6ebe85e96ca647578431e485dbc275e8e8ec5aaf5ff3e8
# Parent folder: ./.cache/pip/http/5/f
# Dirname: e
# Parent folder: ./.cache/pip/http/5/f/e
# Dirname: c
# Parent folder: ./.cache/pip/http/5/f/e/c
# Dirname: 9
# Parent folder: ./.cache/pip/http/5/f/e/c/9
# Filename: 5fec9845948a525eba872c23247b5234b0e6ecd4d26dddcc0edfc053
# Parent folder: ./.cache/pip/selfcheck
# Filename: dc23d26fba1153d5b86af8016c159e8ff2cf9f38081855554ed95daa
# Parent folder: ./.cache/parso
# Dirname: CPython-38-33
# Parent folder: ./.cache/parso/CPython-38-33
# Filename: 17708d38681238dd1bba305ffeb4ac990f31754460f9a2481cbff62497eedbfb-e0ffd4ee79a40d253ca4699c3b91dec4af45b5649d64c1ef7af756bcb112a765.pkl
# Parent folder: ./.cache/parso/CPython-38-33
# Filename: 17708d38681238dd1bba305ffeb4ac990f31754460f9a2481cbff62497eedbfb-ab3f3a1b96a0458e9997f872b9926f945b3a752102f342f1ae64313d0c0a0322.pkl
# Parent folder: ./.cache/parso/CPython-38-33
# Filename: 17708d38681238dd1bba305ffeb4ac990f31754460f9a2481cbff62497eedbfb-261ab1f2a4f84642fe00fa424abfb6155b8d2dc865f6dc8cd1f35aaa4acc9e55.pkl
# Parent folder: ./.cache/parso/CPython-38-33
# Filename: 17708d38681238dd1bba305ffeb4ac990f31754460f9a2481cbff62497eedbfb-57e2700b03eeaa60ebe506a706adcf58bbea9789d1737d800a796c6ac9519ea4.pkl
# Parent folder: ./.cache/parso/CPython-38-33
# Filename: 17708d38681238dd1bba305ffeb4ac990f31754460f9a2481cbff62497eedbfb-0ef14147d7ff88809f8b093a85273731e48a2d0aa5748995e6aca8c9fae54601.pkl
# Parent folder: ./.cache/parso/CPython-38-33
# Filename: 17708d38681238dd1bba305ffeb4ac990f31754460f9a2481cbff62497eedbfb-e4e86084c6ee83a73a36e18172240bc6bd2b56ed4adc7e18576d0c7b53a33b5e.pkl
# Parent folder: ./.cache/parso/CPython-38-33
# Filename: 17708d38681238dd1bba305ffeb4ac990f31754460f9a2481cbff62497eedbfb-ab07083a6c2bc3afcf4989b37e4711fccd3588861b6f80de82d05146ee0380da.pkl
# Parent folder: ./.cache/jedi
# Dirname: CPython-38-33
# Parent folder: ./.cache/jedi/CPython-38-33
# Filename: 5107eb62435166fca767bc009413d9118fad2504d8b16bd76a2db85ef714e9dc-afd1337d8e2b428c6388ab7dad500292b614b1e8f7b92dd481cb382aa3bfb4f1.pkl
# Parent folder: ./.cache/jedi/CPython-38-33
# Filename: 5107eb62435166fca767bc009413d9118fad2504d8b16bd76a2db85ef714e9dc-03fc7ed211e616ccf7c2b16562ff277775d02ef8cbe3492c1d10b3e1bf4df7b2.pkl
# Parent folder: ./.cache/jedi/CPython-38-33
# Filename: 5107eb62435166fca767bc009413d9118fad2504d8b16bd76a2db85ef714e9dc-835a94b8204b8c85ad4bb22874f129cc9ccdb2a273ba3b3be7f909b61b11d014.pkl
# Parent folder: ./.local
# Dirname: share
# Parent folder: ./.local/share
# Dirname: jupyter
# Parent folder: ./.local/share
# Dirname: Trash
# Parent folder: ./.local/share/jupyter
# Dirname: runtime
# Parent folder: ./.local/share/jupyter
# Filename: nbsignatures.db
# Parent folder: ./.local/share/jupyter
# Filename: notebook_secret
# Parent folder: ./.local/share/jupyter/runtime
# Filename: notebook_cookie_secret
# Parent folder: ./.local/share/jupyter/runtime
# Filename: nbserver-11357.json
# Parent folder: ./.local/share/jupyter/runtime
# Filename: nbserver-11357-open.html
# Parent folder: ./.local/share/jupyter/runtime
# Filename: kernel-08b47205-6fd2-44ee-aedf-14656631ad6b.json
# Parent folder: ./.local/share/jupyter/runtime
# Filename: nbserver-2362.json
# Parent folder: ./.local/share/jupyter/runtime
# Filename: nbserver-2362-open.html
# Parent folder: ./.local/share/jupyter/runtime
# Filename: kernel-b5833c9a-84c5-4af4-a1d6-a74677505605.json
# Parent folder: ./.local/share/Trash
# Dirname: files
# Parent folder: ./.local/share/Trash
# Dirname: info
# Parent folder: ./.local/share/Trash/files
# Filename: Untitled1.ipynb
# Parent folder: ./.local/share/Trash/files
# Filename: untitled
# Parent folder: ./.local/share/Trash/files
# Filename: Untitled.ipynb
# Parent folder: ./.local/share/Trash/info
# Filename: Untitled1.ipynb.trashinfo
# Parent folder: ./.local/share/Trash/info
# Filename: untitled.trashinfo
# Parent folder: ./.local/share/Trash/info
# Filename: Untitled.ipynb.trashinfo
# Parent folder: ./.jupyter
# Dirname: nbconfig
# Parent folder: ./.jupyter
# Filename: migrated
# Parent folder: ./.jupyter/nbconfig
# Filename: edit.json
# Parent folder: ./.ipynb_checkpoints
# Filename: 字符串-checkpoint.ipynb
# Parent folder: ./.ipynb_checkpoints
# Filename: 遍历-checkpoint.ipynb
# Parent folder: ./.ipynb_checkpoints
# Filename: 正则-checkpoint.ipynb
# Parent folder: ./.ipython
# Dirname: extensions
# Parent folder: ./.ipython
# Dirname: nbextensions
# Parent folder: ./.ipython
# Dirname: profile_default
# Parent folder: ./.ipython/profile_default
# Dirname: security
# Parent folder: ./.ipython/profile_default
# Dirname: log
# Parent folder: ./.ipython/profile_default
# Dirname: startup
# Parent folder: ./.ipython/profile_default
# Dirname: pid
# Parent folder: ./.ipython/profile_default
# Dirname: db
# Parent folder: ./.ipython/profile_default
# Filename: history.sqlite
# Parent folder: ./.ipython/profile_default/log
# Filename: engines.json
# Parent folder: ./.ipython/profile_default/startup
# Filename: README
# Parent folder: ./.ipython/profile_default/pid
# Filename: ipcontroller.pid
# 0
